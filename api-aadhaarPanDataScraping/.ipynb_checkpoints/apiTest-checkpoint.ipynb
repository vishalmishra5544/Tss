# %%
import base64
import numpy as np
import cv2
from PIL import Image
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import base64
#       2 import numpy as np
# ----> 3 import cv2
#       4 from PIL import Image
#       5 import os
#
# ModuleNotFoundError: No module named 'cv2'

# %%
def img2base64(img, imgType):
    retval, buffer = cv2.imencode(f".{imgType}", img)
    img2Text = base64.b64encode(buffer).decode('utf-8')
    return img2Text

# %%
#test encode and decode
jpg_as_text = img2base64().encode('utf-8')
jpg_original = base64.b64decode(jpg_as_text)
jpg_as_np = np.frombuffer(jpg_original, dtype=np.uint8)
img = Image.fromarray(cv2.imdecode(jpg_as_np, flags=1))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=377x250>

# %%
# !pwd
# Out:
# /media/tssadmin/e60e6319-b20c-4b74-a6d4-c4f138ac4ebf/api-aadhaarPanDataScraping

# %%
reqts = []
for i in os.listdir("/media/tssadmin/e60e6319-b20c-4b74-a6d4-c4f138ac4ebf/aadhaarPanDataScraping/inputTest"):
    img = cv2.imread("/media/tssadmin/e60e6319-b20c-4b74-a6d4-c4f138ac4ebf/aadhaarPanDataScraping/inputTest/"+i)
    temp = i.split(".")
    text = img2base64(img, temp[1])
    req = {
        "requestId": temp[0],
        "imageType": temp[1].upper(),
        "imageData": text,
        "attachmentType": "Card"
    }
    reqts.append(req)

# %%
reqts[5
# Out:
# {'requestId': '20531_PANFront',
#  'imageType': 'JPEG',
#  'imageData': '...',
#  'attachmentType': 'Card'}

# %%
{'requestId': '1205480000038195_23',
 'imageType': 'JPG',
 'imageData': '...',
 'attachmentType': 'Card'}

# %%
{'requestId': '20531_PANFront',
 'imageType': 'JPEG',
 'imageData': '...',
 'attachmentType': 'Card'}

# %%
import random

# %%
random.shuffle(reqts)

# Take a random sample of 500 elements from the shuffled list
sample = reqts[:500]

# %%
import requests
import time

# Set the API endpoint URL
url = "http://127.0.0.1:8000/GetCardDetails/v1"

# Prepare the test data

t = time.time()
ls = []
# Send a POST request to the API endpoint
for data in sample:
    response = requests.post(url, json=data)

    # Check the response status code
    if response.status_code == 200:  # Assuming a successful response has a status code of 200
        # Parse the response JSON data
        response_data = response.json()
        ls.append(response_data)
        print(response_data)
    else:
        print("API request failed with status code:", response.status_code)
total = time.time()- t

# %%
total//500
# Out:
# 1.0
